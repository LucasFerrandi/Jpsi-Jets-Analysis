# %%
import numpy as np
import pandas as pd
import uproot
import utils.hist_utils as hutils # functions created by me
from importlib import reload

# %%
reload(hutils)
hutils.test_utils()
# Out:
# hist_utils.py imported successfully :)
# In order to update it more dinamically, use 'reload' method from 'importlib' library.

# %%
file = uproot.open("/home/ferrandi/alice/datasets/MC/derivedMC/mySkimming/AnalysisResultsTestMakerNoPID14.root")
# file.keys()

# %%
dir_path = '/home/ferrandi/alice/datasets/MC/derivedMC/mySkimming'
fileName = 'AnalysisResultsTestMakerNoPID14.root'
filePath = f"{dir_path}/{fileName}"
rootDir_name = 'table-maker-m-c/Statistics'
histName = "MCsignals"
mcSigHist = hutils.get_hist(filePath, rootDir_name, histName)

# %%
datasets = np.array(['14', '15', '16', '17'])
fileNamesNoPID = 'AnalysisResultsTestMakerNoPID'+datasets+'.root'
fileNamesPID = 'AnalysisResultsTestMakerWithPID'+datasets+'.root'
print(fileNamesNoPID)
print(fileNamesPID)
# Out:
# ['AnalysisResultsTestMakerNoPID14.root'
#  'AnalysisResultsTestMakerNoPID15.root'
#  'AnalysisResultsTestMakerNoPID16.root'
#  'AnalysisResultsTestMakerNoPID17.root']
# ['AnalysisResultsTestMakerWithPID14.root'
#  'AnalysisResultsTestMakerWithPID15.root'
#  'AnalysisResultsTestMakerWithPID16.root'
#  'AnalysisResultsTestMakerWithPID17.root']

# %%
# c1 = ROOT.TCanvas("c1", "MC Signal Histogram", 800, 600)
# mcSigHist.Draw()
# c1.Draw()

# %%
dfMCSig = hutils.hist_to_df(mcSigHist, isLabeledHist=True)
dfMCSig
dftest=pd.DataFrame()
dftest["Label"]=dfMCSig["Label"]
dftest
# Out:
# Converting TH1 histogram to DataFrame...
#                              Label
# 0                        eFromJpsi
# 1                  eFromPromptJpsi
# 2               eFromNonpromptJpsi
# 3                             Jpsi
# 4                    nonPromptJpsi
# 5                       promptJpsi
# 6                 allBeautyHadrons
# 7                            Bplus
# 8                    protonPrimary
# 9  Others (matched to reco tracks)

# %%
dir_path = '/home/ferrandi/alice/datasets/MC/derivedMC/mySkimming'
rootDir_name = 'table-maker-m-c/Statistics'
histName = "MCsignals"
datasetsNames = "LHC25b"+np.array(datasets)
dfMCSigsPID = hutils.join_dfs(dir_path, fileNamesPID, rootDir_name, histName, datasetsNames)
dfMCSigsNoPID = hutils.join_dfs(dir_path, fileNamesNoPID, rootDir_name, histName, datasetsNames)
print(dfMCSigsPID, "\n")
print(dfMCSigsNoPID)
# Out:
# Converting TH1 histogram to DataFrame...
#                             XLabel
# 0                        eFromJpsi
# 1                  eFromPromptJpsi
# 2               eFromNonpromptJpsi
# 3                             Jpsi
# 4                    nonPromptJpsi
# 5                       promptJpsi
# 6                 allBeautyHadrons
# 7                            Bplus
# 8                    protonPrimary
# 9  Others (matched to reco tracks)
# Converting TH1 histogram to DataFrame...
# Converting TH1 histogram to DataFrame...
# Converting TH1 histogram to DataFrame...
# Converting TH1 histogram to DataFrame...
#                             XLabel
# 0                        eFromJpsi
# 1                  eFromPromptJpsi
# 2               eFromNonpromptJpsi
# 3                             Jpsi
# 4                    nonPromptJpsi
# 5                       promptJpsi
# 6                 allBeautyHadrons
# 7                            Bplus
# 8                    protonPrimary
# 9  Others (matched to reco tracks)
# Converting TH1 histogram to DataFrame...
# Converting TH1 histogram to DataFrame...
# Converting TH1 histogram to DataFrame...
#                             XLabel  LHC25b14  LHC25b15  LHC25b16  LHC25b17
# 0                        eFromJpsi   52270.0   81998.0   49250.0   96356.0
# 1                  eFromPromptJpsi   42728.0      32.0   40114.0      26.0
# 2               eFromNonpromptJpsi    9542.0   81966.0    9136.0   96330.0
# 3                             Jpsi   26135.0   41236.0   24625.0   48428.0
# 4                    nonPromptJpsi    4266.0   40983.0    4091.0   48165.0
# 5                       promptJpsi   21364.0     253.0   20057.0     263.0
# 6                 allBeautyHadrons   27736.0  112489.0   26447.0  132348.0
# 7                            Bplus    7060.0   26634.0    6674.0   31764.0
# 8                    protonPrimary  837371.0  824057.0  788726.0  969186.0
# 9  Others (matched to reco tracks)  105759.0  102640.0   98793.0   83813.0
#
#                             XLabel  LHC25b14  LHC25b15  LHC25b16  LHC25b17
# 0                        eFromJpsi   45196.0   71308.0   43074.0   83428.0
# 1                  eFromPromptJpsi   36872.0      30.0   35098.0      24.0
# 2               eFromNonpromptJpsi    8324.0   71278.0    7976.0   83404.0
# 3                             Jpsi   22598.0   35856.0   21537.0   41930.0
# 4                    nonPromptJpsi    3732.0   35639.0    3566.0   41702.0
# 5                       promptJpsi   18436.0     217.0   17549.0     228.0
# 6                 allBeautyHadrons   24163.0   97852.0   23179.0  114806.0
# 7                            Bplus    6132.0   23221.0    5864.0   27458.0
# 8                    protonPrimary  724262.0  716987.0  690681.0  842651.0
# 9  Others (matched to reco tracks)  236112.0  227290.0  232918.0  198498.0

# %%
dfEffMCSigsPID = dfMCSigsPID.copy()
print(dfEffMCSigsPID)
dfEffMCSigsPID.iloc[:,1:] = dfMCSigsNoPID.iloc[:,1:]/dfEffMCSigsPID.iloc[:,1:]
# dfEffMCSigsPID
# Out:
#                             XLabel  LHC25b14  LHC25b15  LHC25b16  LHC25b17
# 0                        eFromJpsi   52270.0   81998.0   49250.0   96356.0
# 1                  eFromPromptJpsi   42728.0      32.0   40114.0      26.0
# 2               eFromNonpromptJpsi    9542.0   81966.0    9136.0   96330.0
# 3                             Jpsi   26135.0   41236.0   24625.0   48428.0
# 4                    nonPromptJpsi    4266.0   40983.0    4091.0   48165.0
# 5                       promptJpsi   21364.0     253.0   20057.0     263.0
# 6                 allBeautyHadrons   27736.0  112489.0   26447.0  132348.0
# 7                            Bplus    7060.0   26634.0    6674.0   31764.0
# 8                    protonPrimary  837371.0  824057.0  788726.0  969186.0
# 9  Others (matched to reco tracks)  105759.0  102640.0   98793.0   83813.0

# %%
dir_path = '/home/ferrandi/alice/datasets/MC/derivedMC/mySkimming'
rootDir_name = 'table-maker-m-c/Statistics'
histName = "EventStats"
datasetsNames = "LHC25b"+np.array(datasets)
dfEvtStatsPID = hutils.join_dfs(dir_path, fileNamesPID, rootDir_name, histName, datasetsNames)
dfEvtStatsNoPID = hutils.join_dfs(dir_path, fileNamesNoPID, rootDir_name, histName, datasetsNames)
# print(dfEvtStatsPID.to_string())
# for i in dfEvtStatsPID(dfEvtStatsPID["XLabel"]=="Before cuts"):
#     print("\n",i)
# Out:
# Converting TH2 histogram to DataFrame...
#                           XLabel                      YLabel
# 0                            BCs                    kIsBBV0A
# 1                            BCs                    kIsBBV0C
# 2                            BCs                    kIsBBFDA
# 3                            BCs                    kIsBBFDC
# 4                            BCs                    kIsBBT0A
# 5                            BCs                    kIsBBT0C
# 6                            BCs                    kNoBGV0A
# 7                            BCs                    kNoBGV0C
# 8                            BCs                    kNoBGFDA
# 9                            BCs                    kNoBGFDC
# 10                           BCs                    kNoBGT0A
# 11                           BCs                    kNoBGT0C
# 12                           BCs                    kIsBBZNA
# 13                           BCs                    kIsBBZNC
# 14                           BCs                    kIsBBZAC
# 15                           BCs                    kNoBGZNA
# 16                           BCs                    kNoBGZNC
# 17                           BCs          kNoV0MOnVsOfPileup
# 18                           BCs          kNoSPDOnVsOfPileup
# 19                           BCs             kNoV0Casymmetry
# 20                           BCs            kIsGoodTimeRange
# 21                           BCs            kNoIncompleteDAQ
# 22                           BCs           kNoTPCLaserWarmUp
# 23                           BCs                 kNoTPCHVdip
# 24                           BCs            kNoPileupFromSPD
# 25                           BCs               kNoV0PFPileup
# 26                           BCs            kNoSPDClsVsTklBG
# 27                           BCs            kNoV0C012vsTklBG
# 28                           BCs          kNoInconsistentVtx
# 29                           BCs         kNoPileupInMultBins
# 30                           BCs                 kNoPileupMV
# 31                           BCs                kNoPileupTPC
# 32                           BCs               kIsTriggerTVX
# 33                           BCs                     kIsINT1
# 34                           BCs         kNoITSROFrameBorder
# 35                           BCs          kNoTimeFrameBorder
# 36                           BCs          kNoSameBunchPileup
# 37                           BCs          kIsGoodZvtxFT0vsPV
# 38                           BCs             kIsVertexITSTPC
# 39                           BCs         kIsVertexTOFmatched
# 40                           BCs         kIsVertexTRDmatched
# 41                           BCs    kNoCollInTimeRangeNarrow
# 42                           BCs    kNoCollInTimeRangeStrict
# 43                           BCs  kNoCollInTimeRangeStandard
# 44                           BCs          kNoCollInRofStrict
# 45                           BCs        kNoCollInRofStandard
# 46                           BCs    kNoHighMultCollInPrevRof
# 47                           BCs            kIsGoodITSLayer3
# 48                           BCs         kIsGoodITSLayer0123
# 49                           BCs         kIsGoodITSLayersAll
# 50                           BCs                       Total
# 51   Collisions before filtering                    kIsBBV0A
# 52   Collisions before filtering                    kIsBBV0C
# 53   Collisions before filtering                    kIsBBFDA
# 54   Collisions before filtering                    kIsBBFDC
# 55   Collisions before filtering                    kIsBBT0A
# 56   Collisions before filtering                    kIsBBT0C
# 57   Collisions before filtering                    kNoBGV0A
# 58   Collisions before filtering                    kNoBGV0C
# 59   Collisions before filtering                    kNoBGFDA
# 60   Collisions before filtering                    kNoBGFDC
# 61   Collisions before filtering                    kNoBGT0A
# 62   Collisions before filtering                    kNoBGT0C
# 63   Collisions before filtering                    kIsBBZNA
# 64   Collisions before filtering                    kIsBBZNC
# 65   Collisions before filtering                    kIsBBZAC
# 66   Collisions before filtering                    kNoBGZNA
# 67   Collisions before filtering                    kNoBGZNC
# 68   Collisions before filtering          kNoV0MOnVsOfPileup
# 69   Collisions before filtering          kNoSPDOnVsOfPileup
# 70   Collisions before filtering             kNoV0Casymmetry
# 71   Collisions before filtering            kIsGoodTimeRange
# 72   Collisions before filtering            kNoIncompleteDAQ
# 73   Collisions before filtering           kNoTPCLaserWarmUp
# 74   Collisions before filtering                 kNoTPCHVdip
# 75   Collisions before filtering            kNoPileupFromSPD
# 76   Collisions before filtering               kNoV0PFPileup
# 77   Collisions before filtering            kNoSPDClsVsTklBG
# 78   Collisions before filtering            kNoV0C012vsTklBG
# 79   Collisions before filtering          kNoInconsistentVtx
# 80   Collisions before filtering         kNoPileupInMultBins
# 81   Collisions before filtering                 kNoPileupMV
# 82   Collisions before filtering                kNoPileupTPC
# 83   Collisions before filtering               kIsTriggerTVX
# 84   Collisions before filtering                     kIsINT1
# 85   Collisions before filtering         kNoITSROFrameBorder
# 86   Collisions before filtering          kNoTimeFrameBorder
# 87   Collisions before filtering          kNoSameBunchPileup
# 88   Collisions before filtering          kIsGoodZvtxFT0vsPV
# 89   Collisions before filtering             kIsVertexITSTPC
# 90   Collisions before filtering         kIsVertexTOFmatched
# 91   Collisions before filtering         kIsVertexTRDmatched
# 92   Collisions before filtering    kNoCollInTimeRangeNarrow
# 93   Collisions before filtering    kNoCollInTimeRangeStrict
# 94   Collisions before filtering  kNoCollInTimeRangeStandard
# 95   Collisions before filtering          kNoCollInRofStrict
# 96   Collisions before filtering        kNoCollInRofStandard
# 97   Collisions before filtering    kNoHighMultCollInPrevRof
# 98   Collisions before filtering            kIsGoodITSLayer3
# 99   Collisions before filtering         kIsGoodITSLayer0123
# 100  Collisions before filtering         kIsGoodITSLayersAll
# 101  Collisions before filtering                       Total
# 102                  Before cuts                    kIsBBV0A
# 103                  Before cuts                    kIsBBV0C
# 104                  Before cuts                    kIsBBFDA
# 105                  Before cuts                    kIsBBFDC
# 106                  Before cuts                    kIsBBT0A
# 107                  Before cuts                    kIsBBT0C
# 108                  Before cuts                    kNoBGV0A
# 109                  Before cuts                    kNoBGV0C
# 110                  Before cuts                    kNoBGFDA
# 111                  Before cuts                    kNoBGFDC
# 112                  Before cuts                    kNoBGT0A
# 113                  Before cuts                    kNoBGT0C
# 114                  Before cuts                    kIsBBZNA
# 115                  Before cuts                    kIsBBZNC
# 116                  Before cuts                    kIsBBZAC
# 117                  Before cuts                    kNoBGZNA
# 118                  Before cuts                    kNoBGZNC
# 119                  Before cuts          kNoV0MOnVsOfPileup
# 120                  Before cuts          kNoSPDOnVsOfPileup
# 121                  Before cuts             kNoV0Casymmetry
# 122                  Before cuts            kIsGoodTimeRange
# 123                  Before cuts            kNoIncompleteDAQ
# 124                  Before cuts           kNoTPCLaserWarmUp
# 125                  Before cuts                 kNoTPCHVdip
# 126                  Before cuts            kNoPileupFromSPD
# 127                  Before cuts               kNoV0PFPileup
# 128                  Before cuts            kNoSPDClsVsTklBG
# 129                  Before cuts            kNoV0C012vsTklBG
# 130                  Before cuts          kNoInconsistentVtx
# 131                  Before cuts         kNoPileupInMultBins
# 132                  Before cuts                 kNoPileupMV
# 133                  Before cuts                kNoPileupTPC
# 134                  Before cuts               kIsTriggerTVX
# 135                  Before cuts                     kIsINT1
# 136                  Before cuts         kNoITSROFrameBorder
# 137                  Before cuts          kNoTimeFrameBorder
# 138                  Before cuts          kNoSameBunchPileup
# 139                  Before cuts          kIsGoodZvtxFT0vsPV
# 140                  Before cuts             kIsVertexITSTPC
# 141                  Before cuts         kIsVertexTOFmatched
# 142                  Before cuts         kIsVertexTRDmatched
# 143                  Before cuts    kNoCollInTimeRangeNarrow
# 144                  Before cuts    kNoCollInTimeRangeStrict
# 145                  Before cuts  kNoCollInTimeRangeStandard
# 146                  Before cuts          kNoCollInRofStrict
# 147                  Before cuts        kNoCollInRofStandard
# 148                  Before cuts    kNoHighMultCollInPrevRof
# 149                  Before cuts            kIsGoodITSLayer3
# 150                  Before cuts         kIsGoodITSLayer0123
# 151                  Before cuts         kIsGoodITSLayersAll
# 152                  Before cuts                       Total
# 153                   After cuts                    kIsBBV0A
# 154                   After cuts                    kIsBBV0C
# 155                   After cuts                    kIsBBFDA
# 156                   After cuts                    kIsBBFDC
# 157                   After cuts                    kIsBBT0A
# 158                   After cuts                    kIsBBT0C
# 159                   After cuts                    kNoBGV0A
# 160                   After cuts                    kNoBGV0C
# 161                   After cuts                    kNoBGFDA
# 162                   After cuts                    kNoBGFDC
# 163                   After cuts                    kNoBGT0A
# 164                   After cuts                    kNoBGT0C
# 165                   After cuts                    kIsBBZNA
# 166                   After cuts                    kIsBBZNC
# 167                   After cuts                    kIsBBZAC
# 168                   After cuts                    kNoBGZNA
# 169                   After cuts                    kNoBGZNC
# 170                   After cuts          kNoV0MOnVsOfPileup
# 171                   After cuts          kNoSPDOnVsOfPileup
# 172                   After cuts             kNoV0Casymmetry
# 173                   After cuts            kIsGoodTimeRange
# 174                   After cuts            kNoIncompleteDAQ
# 175                   After cuts           kNoTPCLaserWarmUp
# 176                   After cuts                 kNoTPCHVdip
# 177                   After cuts            kNoPileupFromSPD
# 178                   After cuts               kNoV0PFPileup
# 179                   After cuts            kNoSPDClsVsTklBG
# 180                   After cuts            kNoV0C012vsTklBG
# 181                   After cuts          kNoInconsistentVtx
# 182                   After cuts         kNoPileupInMultBins
# 183                   After cuts                 kNoPileupMV
# 184                   After cuts                kNoPileupTPC
# 185                   After cuts               kIsTriggerTVX
# 186                   After cuts                     kIsINT1
# 187                   After cuts         kNoITSROFrameBorder
# 188                   After cuts          kNoTimeFrameBorder
# 189                   After cuts          kNoSameBunchPileup
# 190                   After cuts          kIsGoodZvtxFT0vsPV
# 191                   After cuts             kIsVertexITSTPC
# 192                   After cuts         kIsVertexTOFmatched
# 193                   After cuts         kIsVertexTRDmatched
# 194                   After cuts    kNoCollInTimeRangeNarrow
# 195                   After cuts    kNoCollInTimeRangeStrict
# 196                   After cuts  kNoCollInTimeRangeStandard
# 197                   After cuts          kNoCollInRofStrict
# 198                   After cuts        kNoCollInRofStandard
# 199                   After cuts    kNoHighMultCollInPrevRof
# 200                   After cuts            kIsGoodITSLayer3
# 201                   After cuts         kIsGoodITSLayer0123
# 202                   After cuts         kIsGoodITSLayersAll
# 203                   After cuts                       Total
# Converting TH2 histogram to DataFrame...
# Converting TH2 histogram to DataFrame...
# Converting TH2 histogram to DataFrame...
# Converting TH2 histogram to DataFrame...
#                           XLabel                      YLabel
# 0                            BCs                    kIsBBV0A
# 1                            BCs                    kIsBBV0C
# 2                            BCs                    kIsBBFDA
# 3                            BCs                    kIsBBFDC
# 4                            BCs                    kIsBBT0A
# 5                            BCs                    kIsBBT0C
# 6                            BCs                    kNoBGV0A
# 7                            BCs                    kNoBGV0C
# 8                            BCs                    kNoBGFDA
# 9                            BCs                    kNoBGFDC
# 10                           BCs                    kNoBGT0A
# 11                           BCs                    kNoBGT0C
# 12                           BCs                    kIsBBZNA
# 13                           BCs                    kIsBBZNC
# 14                           BCs                    kIsBBZAC
# 15                           BCs                    kNoBGZNA
# 16                           BCs                    kNoBGZNC
# 17                           BCs          kNoV0MOnVsOfPileup
# 18                           BCs          kNoSPDOnVsOfPileup
# 19                           BCs             kNoV0Casymmetry
# 20                           BCs            kIsGoodTimeRange
# 21                           BCs            kNoIncompleteDAQ
# 22                           BCs           kNoTPCLaserWarmUp
# 23                           BCs                 kNoTPCHVdip
# 24                           BCs            kNoPileupFromSPD
# 25                           BCs               kNoV0PFPileup
# 26                           BCs            kNoSPDClsVsTklBG
# 27                           BCs            kNoV0C012vsTklBG
# 28                           BCs          kNoInconsistentVtx
# 29                           BCs         kNoPileupInMultBins
# 30                           BCs                 kNoPileupMV
# 31                           BCs                kNoPileupTPC
# 32                           BCs               kIsTriggerTVX
# 33                           BCs                     kIsINT1
# 34                           BCs         kNoITSROFrameBorder
# 35                           BCs          kNoTimeFrameBorder
# 36                           BCs          kNoSameBunchPileup
# 37                           BCs          kIsGoodZvtxFT0vsPV
# 38                           BCs             kIsVertexITSTPC
# 39                           BCs         kIsVertexTOFmatched
# 40                           BCs         kIsVertexTRDmatched
# 41                           BCs    kNoCollInTimeRangeNarrow
# 42                           BCs    kNoCollInTimeRangeStrict
# 43                           BCs  kNoCollInTimeRangeStandard
# 44                           BCs          kNoCollInRofStrict
# 45                           BCs        kNoCollInRofStandard
# 46                           BCs    kNoHighMultCollInPrevRof
# 47                           BCs            kIsGoodITSLayer3
# 48                           BCs         kIsGoodITSLayer0123
# 49                           BCs         kIsGoodITSLayersAll
# 50                           BCs                       Total
# 51   Collisions before filtering                    kIsBBV0A
# 52   Collisions before filtering                    kIsBBV0C
# 53   Collisions before filtering                    kIsBBFDA
# 54   Collisions before filtering                    kIsBBFDC
# 55   Collisions before filtering                    kIsBBT0A
# 56   Collisions before filtering                    kIsBBT0C
# 57   Collisions before filtering                    kNoBGV0A
# 58   Collisions before filtering                    kNoBGV0C
# 59   Collisions before filtering                    kNoBGFDA
# 60   Collisions before filtering                    kNoBGFDC
# 61   Collisions before filtering                    kNoBGT0A
# 62   Collisions before filtering                    kNoBGT0C
# 63   Collisions before filtering                    kIsBBZNA
# 64   Collisions before filtering                    kIsBBZNC
# 65   Collisions before filtering                    kIsBBZAC
# 66   Collisions before filtering                    kNoBGZNA
# 67   Collisions before filtering                    kNoBGZNC
# 68   Collisions before filtering          kNoV0MOnVsOfPileup
# 69   Collisions before filtering          kNoSPDOnVsOfPileup
# 70   Collisions before filtering             kNoV0Casymmetry
# 71   Collisions before filtering            kIsGoodTimeRange
# 72   Collisions before filtering            kNoIncompleteDAQ
# 73   Collisions before filtering           kNoTPCLaserWarmUp
# 74   Collisions before filtering                 kNoTPCHVdip
# 75   Collisions before filtering            kNoPileupFromSPD
# 76   Collisions before filtering               kNoV0PFPileup
# 77   Collisions before filtering            kNoSPDClsVsTklBG
# 78   Collisions before filtering            kNoV0C012vsTklBG
# 79   Collisions before filtering          kNoInconsistentVtx
# 80   Collisions before filtering         kNoPileupInMultBins
# 81   Collisions before filtering                 kNoPileupMV
# 82   Collisions before filtering                kNoPileupTPC
# 83   Collisions before filtering               kIsTriggerTVX
# 84   Collisions before filtering                     kIsINT1
# 85   Collisions before filtering         kNoITSROFrameBorder
# 86   Collisions before filtering          kNoTimeFrameBorder
# 87   Collisions before filtering          kNoSameBunchPileup
# 88   Collisions before filtering          kIsGoodZvtxFT0vsPV
# 89   Collisions before filtering             kIsVertexITSTPC
# 90   Collisions before filtering         kIsVertexTOFmatched
# 91   Collisions before filtering         kIsVertexTRDmatched
# 92   Collisions before filtering    kNoCollInTimeRangeNarrow
# 93   Collisions before filtering    kNoCollInTimeRangeStrict
# 94   Collisions before filtering  kNoCollInTimeRangeStandard
# 95   Collisions before filtering          kNoCollInRofStrict
# 96   Collisions before filtering        kNoCollInRofStandard
# 97   Collisions before filtering    kNoHighMultCollInPrevRof
# 98   Collisions before filtering            kIsGoodITSLayer3
# 99   Collisions before filtering         kIsGoodITSLayer0123
# 100  Collisions before filtering         kIsGoodITSLayersAll
# 101  Collisions before filtering                       Total
# 102                  Before cuts                    kIsBBV0A
# 103                  Before cuts                    kIsBBV0C
# 104                  Before cuts                    kIsBBFDA
# 105                  Before cuts                    kIsBBFDC
# 106                  Before cuts                    kIsBBT0A
# 107                  Before cuts                    kIsBBT0C
# 108                  Before cuts                    kNoBGV0A
# 109                  Before cuts                    kNoBGV0C
# 110                  Before cuts                    kNoBGFDA
# 111                  Before cuts                    kNoBGFDC
# 112                  Before cuts                    kNoBGT0A
# 113                  Before cuts                    kNoBGT0C
# 114                  Before cuts                    kIsBBZNA
# 115                  Before cuts                    kIsBBZNC
# 116                  Before cuts                    kIsBBZAC
# 117                  Before cuts                    kNoBGZNA
# 118                  Before cuts                    kNoBGZNC
# 119                  Before cuts          kNoV0MOnVsOfPileup
# 120                  Before cuts          kNoSPDOnVsOfPileup
# 121                  Before cuts             kNoV0Casymmetry
# 122                  Before cuts            kIsGoodTimeRange
# 123                  Before cuts            kNoIncompleteDAQ
# 124                  Before cuts           kNoTPCLaserWarmUp
# 125                  Before cuts                 kNoTPCHVdip
# 126                  Before cuts            kNoPileupFromSPD
# 127                  Before cuts               kNoV0PFPileup
# 128                  Before cuts            kNoSPDClsVsTklBG
# 129                  Before cuts            kNoV0C012vsTklBG
# 130                  Before cuts          kNoInconsistentVtx
# 131                  Before cuts         kNoPileupInMultBins
# 132                  Before cuts                 kNoPileupMV
# 133                  Before cuts                kNoPileupTPC
# 134                  Before cuts               kIsTriggerTVX
# 135                  Before cuts                     kIsINT1
# 136                  Before cuts         kNoITSROFrameBorder
# 137                  Before cuts          kNoTimeFrameBorder
# 138                  Before cuts          kNoSameBunchPileup
# 139                  Before cuts          kIsGoodZvtxFT0vsPV
# 140                  Before cuts             kIsVertexITSTPC
# 141                  Before cuts         kIsVertexTOFmatched
# 142                  Before cuts         kIsVertexTRDmatched
# 143                  Before cuts    kNoCollInTimeRangeNarrow
# 144                  Before cuts    kNoCollInTimeRangeStrict
# 145                  Before cuts  kNoCollInTimeRangeStandard
# 146                  Before cuts          kNoCollInRofStrict
# 147                  Before cuts        kNoCollInRofStandard
# 148                  Before cuts    kNoHighMultCollInPrevRof
# 149                  Before cuts            kIsGoodITSLayer3
# 150                  Before cuts         kIsGoodITSLayer0123
# 151                  Before cuts         kIsGoodITSLayersAll
# 152                  Before cuts                       Total
# 153                   After cuts                    kIsBBV0A
# 154                   After cuts                    kIsBBV0C
# 155                   After cuts                    kIsBBFDA
# 156                   After cuts                    kIsBBFDC
# 157                   After cuts                    kIsBBT0A
# 158                   After cuts                    kIsBBT0C
# 159                   After cuts                    kNoBGV0A
# 160                   After cuts                    kNoBGV0C
# 161                   After cuts                    kNoBGFDA
# 162                   After cuts                    kNoBGFDC
# 163                   After cuts                    kNoBGT0A
# 164                   After cuts                    kNoBGT0C
# 165                   After cuts                    kIsBBZNA
# 166                   After cuts                    kIsBBZNC
# 167                   After cuts                    kIsBBZAC
# 168                   After cuts                    kNoBGZNA
# 169                   After cuts                    kNoBGZNC
# 170                   After cuts          kNoV0MOnVsOfPileup
# 171                   After cuts          kNoSPDOnVsOfPileup
# 172                   After cuts             kNoV0Casymmetry
# 173                   After cuts            kIsGoodTimeRange
# 174                   After cuts            kNoIncompleteDAQ
# 175                   After cuts           kNoTPCLaserWarmUp
# 176                   After cuts                 kNoTPCHVdip
# 177                   After cuts            kNoPileupFromSPD
# 178                   After cuts               kNoV0PFPileup
# 179                   After cuts            kNoSPDClsVsTklBG
# 180                   After cuts            kNoV0C012vsTklBG
# 181                   After cuts          kNoInconsistentVtx
# 182                   After cuts         kNoPileupInMultBins
# 183                   After cuts                 kNoPileupMV
# 184                   After cuts                kNoPileupTPC
# 185                   After cuts               kIsTriggerTVX
# 186                   After cuts                     kIsINT1
# 187                   After cuts         kNoITSROFrameBorder
# 188                   After cuts          kNoTimeFrameBorder
# 189                   After cuts          kNoSameBunchPileup
# 190                   After cuts          kIsGoodZvtxFT0vsPV
# 191                   After cuts             kIsVertexITSTPC
# 192                   After cuts         kIsVertexTOFmatched
# 193                   After cuts         kIsVertexTRDmatched
# 194                   After cuts    kNoCollInTimeRangeNarrow
# 195                   After cuts    kNoCollInTimeRangeStrict
# 196                   After cuts  kNoCollInTimeRangeStandard
# 197                   After cuts          kNoCollInRofStrict
# 198                   After cuts        kNoCollInRofStandard
# 199                   After cuts    kNoHighMultCollInPrevRof
# 200                   After cuts            kIsGoodITSLayer3
# 201                   After cuts         kIsGoodITSLayer0123
# 202                   After cuts         kIsGoodITSLayersAll
# 203                   After cuts                       Total
# Converting TH2 histogram to DataFrame...
# Converting TH2 histogram to DataFrame...
# Converting TH2 histogram to DataFrame...

# %%
dfEvtStatsPIDAfterCuts = dfEvtStatsPID.query("XLabel == 'After cuts' and YLabel == 'Total' ")
dfEvtStatsPIDBeforeCuts = dfEvtStatsPID.query("XLabel == 'Before cuts' and YLabel == 'Total' ")
#and YLabel == 'Total' ")
dfEvtStatsNoPIDAfterCuts = dfEvtStatsNoPID.query("XLabel == 'After cuts' and YLabel == 'Total' ")
dfEvtStatsNoPIDBeforeCuts = dfEvtStatsNoPID.query("XLabel == 'Before cuts' and YLabel == 'Total' ")

print(dfEvtStatsPIDAfterCuts, "\n")
print(dfEvtStatsPIDBeforeCuts, "\n")
print(dfEvtStatsNoPIDAfterCuts, "\n")
print(dfEvtStatsNoPIDBeforeCuts, "\n")
print("\n")

dfEffEvtStatsPID = dfEvtStatsPIDAfterCuts.copy()
dfEffEvtStatsPID.iloc[:, 2:] = (
    dfEffEvtStatsPID.iloc[:, 2:] /
    dfEvtStatsPIDBeforeCuts.iloc[:, 2:].values
)
dfEffEvtStatsPID["XLabel"] = "Cuts Efficiency With PID"
dfEffEvtStatsPID.drop(columns=["YLabel"], inplace=True)
print(dfEffEvtStatsPID)

dfEffEvtStatsNoPID = dfEvtStatsNoPIDAfterCuts.copy()
dfEffEvtStatsNoPID.iloc[:, 2:] = (
    dfEffEvtStatsNoPID.iloc[:, 2:] /
    dfEvtStatsNoPIDBeforeCuts.iloc[:, 2:].values
)
dfEffEvtStatsNoPID["XLabel"] = "Cuts Efficiency W/o PID"
dfEffEvtStatsNoPID.drop(columns=["YLabel"], inplace=True)
print(dfEffEvtStatsNoPID)
# Out:
#          XLabel YLabel  LHC25b14  LHC25b15  LHC25b16  LHC25b17
# 203  After cuts  Total   80424.0   83624.0   74187.0   68730.0
#
#           XLabel YLabel  LHC25b14  LHC25b15  LHC25b16  LHC25b17
# 152  Before cuts  Total  115517.0  119517.0  108640.0   99679.0
#
#          XLabel YLabel  LHC25b14  LHC25b15  LHC25b16  LHC25b17
# 203  After cuts  Total   69752.0   72742.0   64941.0   60287.0
#
#           XLabel YLabel  LHC25b14  LHC25b15  LHC25b16  LHC25b17
# 152  Before cuts  Total  100018.0  103921.0   94958.0   87301.0
#
#
#
#                        XLabel  LHC25b14  LHC25b15  LHC25b16  LHC25b17
# 203  Cuts Efficiency With PID  0.696209  0.699683   0.68287  0.689513
#                       XLabel  LHC25b14  LHC25b15  LHC25b16  LHC25b17
# 203  Cuts Efficiency W/o PID  0.697394  0.699974  0.683892  0.690565
