# %%
import ROOT
import utils.hist_utils as hutils # functions created by me
from importlib import reload

# %%
reload(hutils)
hutils.test_utils() # just to test that the module is correctly reloaded
# Out:
# hist_utils.py imported successfully :)
# In order to update it more dinamically, use 'reload' method from 'importlib' library.

# %%
# Data
dir_path = '~/alice/datasets/data/andreasDQ_LHC24am_pass1_skimmed_TableMaker_JE/alihyperloop/jobs/0363/hy_3638541/AOD/001'
filename = 'AO2D.root'
path_data = f"{dir_path}/{filename}"

# %%
reload(hutils)
hutils.merge_TDirs(path_data)
# Out:
# target dir type:  <class cppyy.gbl.TDirectoryFile at 0xe9d1a90>
# dir:  Name: DF_2387821458587072 Title: DF_2387821458587072
# DF found:  DF_2387821458587072
# treeKey Name:  O2reducedevent
# treeKey Name:  O2reducedtrack
# treeKey Name:  O2reduceventinfo
# treeKey Name:  O2revtxcov
# treeKey Name:  O2rtassoc
# treeKey Name:  O2rtbarrel
# treeKey Name:  O2rtbarrelcov
# treeKey Name:  O2rtbarrelinfo
# treeKey Name:  O2rtbarrelpid
# dir:  Name: DF_2387821458610528 Title: DF_2387821458610528
# DF found:  DF_2387821458610528
# treeKey Name:  O2reducedevent
# treeKey Name:  O2reducedtrack
# treeKey Name:  O2reduceventinfo
# treeKey Name:  O2revtxcov
# treeKey Name:  O2rtassoc
# treeKey Name:  O2rtbarrel
# treeKey Name:  O2rtbarrelcov
# treeKey Name:  O2rtbarrelinfo
# treeKey Name:  O2rtbarrelpid
# dir:  Name: DF_2387821458638784 Title: DF_2387821458638784
# DF found:  DF_2387821458638784
# treeKey Name:  O2reducedevent
# treeKey Name:  O2reducedtrack
# treeKey Name:  O2reduceventinfo
# ...
