# %%
import pandas as pd
import numpy as np

# %%
FILE = "output/MultiClass/bdt_pt0_100.parquet.gzip"
# Read file
df = pd.read_parquet(FILE)

# %%
# Basic information
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Shape: (185, 75)
#
# Columns:
# ...

# %%
# First rows
print("\nFirst 5 rows:")
print(df.head(5))
# Out:
# First 5 rows:
#       fMass       fPt      fEta      fPhi  fSign  fFilterMap  fMcDecision  \
# 0  4.107707  5.490532  0.308578  1.161150      0           1            0
# 1  4.465432  8.650932 -0.200566  0.444761      0           1            0
# 2  2.923578  1.834178 -0.295154  2.326879      0           1            0
# 3  2.587787  0.833581 -1.137617  2.925815      0           1            0
# 4  3.849010  0.716627  1.275526  5.267569      0           1            0
#
#        fPt1     fEta1     fPhi1  ...  fDeviationxyPairKF  fMassKFGeoTop  \
# 0  2.873953 -0.235652  1.689863  ...           -0.270727       4.125660
# 1  6.400438 -0.108551  0.768503  ...            0.543288       4.465180
# 2  2.023432  0.088717  1.663530  ...           -1.311158       2.917267
# 3  1.534878 -0.180097  2.182683  ...            0.744758       2.587337
# 4  2.053559  0.094931  4.270244  ...            1.390950       3.857491
#
#    fChi2OverNDFKFGeoTop     fTauz    fTauxy       fLz      fLxy  \
# ...
