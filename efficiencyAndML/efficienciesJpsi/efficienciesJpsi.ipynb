# %%
import ROOT
import utils.hist_utils as hutils # functions created by me
from importlib import reload
import numpy as np
# %jsroot on
hutils.test_utils()
# Out:
# hist_utils.py imported successfully :)
# In order to update it more dinamically, use 'reload' method from 'importlib' library.

# %%
# dir_path = '~/alice/Jpsi-Jets-Analysis/workDir/MC/DQEfficiency/skimmingByOthers'
dir_path='~/alice/Jpsi-Jets-Analysis/workDir/MC/DQEfficiency/mySkimming/completeMC/output'
# filename = 'LHC25b16jpsiKineDcaQualitynoPID2-26-05-01.root'
filename16 = '16YFullStat26-05-07.root'
#~/alice/Jpsi-Jets-Analysis/workDir/MC/DQEfficiency/mySkimming/completeMC/output
# filename = 'LHC25b16_MCSignals25-08-25.root'
path25b16 = f"{dir_path}/{filename16}"

tckCut = "jpsiKineDcaQualitynoPID2"
outDir = f"output/efficienciesJpsi/cutOnY/{tckCut}"
colors = [ROOT.kRed-2, ROOT.kBlue-2, ROOT.kOrange-2, ROOT.kGreen-1]
#Alice suggested colors: kBlack, kRed+1 , kBlue+1, kGreen+3, kMagenta+1, kOrange-1,kCyan+2,kYellow+2

# %%
# Binning

# ptBinsGeomFine = createGeomPtBins() # Good for the plots using eta (wrong plots!)
xMin, xMax, nBins, beta = 1.0, 20.0, 17, 1.0 # 1.0, 20.0, 17, 1.0
usedPtBins = hutils.createGeomPtBins2(xMin, xMax, nBins, beta=beta)

# %% [markdown]
# # LHC25b16

# %% [markdown]
# ## Prompt

# %%
# Prompt
MCDataset = "LHC25b16"
reload(hutils)
logX = True
if logX:
    legPos = [0.1, 0.65, 0.5, 0.85]
    logXLabel="LogX"
else:
    legPos = [0.35, 0.2, 0.85, 0.4]
    logXLabel=""
graph25b16Prompt, leg25b16Prompt = hutils.EfficiencyPlot(
    listA=f"PairsBarrelSEPMCorrectAssoc_{tckCut}_eePrimaryFromPromptJPsi",
    listB="MCTruthGenSel_promptJpsi",
    path=path25b16,
    # graph_title="Prompt J/#psi Reconstruction Efficiency",
    # legText=f"{MCDataset}, prompt",
    ptBins = usedPtBins,
    JpsiType="Prompt",
    legPos=legPos
)

# %%
c25b16Prompt = ROOT.TCanvas()
# graph25b16Prompt.SetTitle("Prompt J/#psi Reconstruction Efficiency") #Change previous title
graph25b16Prompt.Draw("AP")
if logX:
    ROOT.gPad.SetLogx()
leg25b16Prompt.Draw()
c25b16Prompt.Draw()
pdf_name = f"promptRecoEff{MCDataset}{logXLabel}.pdf"
svg_name = f"promptRecoEff{MCDataset}{logXLabel}.svg"
c25b16Prompt.Print(f"{outDir}/{pdf_name}")
c25b16Prompt.Print(f"{outDir}/{svg_name}")
# Out:
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/promptRecoEffLHC25b16LogX.pdf has been created
# Info in <TCanvas::Print>: SVG file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/promptRecoEffLHC25b16LogX.svg has been created
# <div id="root_plot_1778658868358" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778658868358(Core) {
# ...

# %%
# IncorrectAssoc
MCDataset = "LHC25b16"
logX = False
if logX:
    legPos = [0.1, 0.65, 0.5, 0.85]
    logXLabel="LogX"
else:
    legPos = [0.35, 0.2, 0.85, 0.4]
    logXLabel=""
graph25b16IncPrompt, leg25b16IncPrompt = hutils.EfficiencyPlot(
    listA=f"PairsBarrelSEPMIncorrectAssoc_{tckCut}_eePrimaryFromPromptJPsi",
    listB="MCTruthGenSel_promptJpsi",
    path=path25b16,
    # graph_title="Prompt J/#psi Reconstruction Efficiency",
    # legText=f"{MCDataset}, prompt",
    ptBins = usedPtBins,
    JpsiType="",
    legPos=legPos
)

c25b16IncPrompt = ROOT.TCanvas()
# graph25b16IncPrompt.SetTitle("Prompt J/#psi Reconstruction Efficiency") #Change previous title
graph25b16IncPrompt.Draw("AP")
if logX:
    ROOT.gPad.SetLogx()
leg25b16IncPrompt.Draw()
c25b16IncPrompt.Draw()
pdf_name = f"promptIncorrectAssocRecoEff{MCDataset}{logXLabel}.pdf"
svg_name = f"promptRecoEff{MCDataset}{logXLabel}.svg"
c25b16IncPrompt.Print(f"{outDir}/{pdf_name}")
c25b16IncPrompt.Print(f"{outDir}/{svg_name}")
# Out:
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/promptIncorrectAssocRecoEffLHC25b16.pdf has been created
# Info in <TCanvas::Print>: SVG file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/promptRecoEffLHC25b16.svg has been created
# <div id="root_plot_1778592429690" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778592429690(Core) {
# ...

# %% [markdown]
# ## Non prompt

# %%
# Non prompt
graph25b16NonPrompt, leg25b16NonPrompt = hutils.EfficiencyPlot(
    listA=f"PairsBarrelSEPMCorrectAssoc_{tckCut}_eePrimaryFromNonPromptJPsi",
    listB="MCTruthGenSel_nonPromptJpsi",
    path=path25b16,
    graph_title="Non Prompt J/#psi Reconstruction Efficiency",
    legText="LHC25b16, non-prompt",
    ptBins = usedPtBins
)

# %%
c25b16NonPrompt = ROOT.TCanvas()
graph25b16NonPrompt.SetTitle("Non Prompt J/#psi Reconstruction Efficiency")
graph25b16NonPrompt.Draw("AP")
leg25b16NonPrompt.Draw()
c25b16NonPrompt.Draw()
pdf_name = f"nonPromptRecoEff{MCDataset}.pdf"
c25b16NonPrompt.Print(f"{outDir}/{pdf_name}")
# Out:
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/nonPromptRecoEffLHC25b16.pdf has been created
# <div id="root_plot_1778588072772" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588072772(Core) {
# ...

# %% [markdown]
# ## LHC25b16 comparison

# %%
graphs = [graph25b16Prompt, graph25b16NonPrompt]
legends = [leg25b16NonPrompt, leg25b16Prompt]

n = len(graphs)
cAll = ROOT.TCanvas("cAll16", "Side by Side", 500*n , 400)

cAll.Divide(n, 1)
for i, (g, leg) in enumerate(zip(graphs, legends), start=1):
    cAll.cd(i)
    g.Draw("AP")
    leg.Draw()

cAll.Draw()
# Out:
# <div id="root_plot_1778588072920" style="width: 1000px; height: 400px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588072920(Core) {
# ...

# %%
c25b16 = ROOT.TCanvas("c25b16", "c25b16", 800, 600)
graph25b16Prompt.SetLineColor(colors[0])
graph25b16Prompt.SetMarkerColor(colors[0])
# graph25b16NonPrompt.SetTitle("J/#psi Reconstruction Efficiency")
graph25b16NonPrompt.Draw("AP") # graph with greater axis must be drawn first
graph25b16Prompt.Draw("P SAME")
leg25b16 = leg25b16Prompt.Clone("leg25b16")
# legendPrompt.Draw()
leg25b16.AddEntry(graph25b16NonPrompt, "LHC25b16, non-prompt", "p")
leg25b16.Draw()
c25b16.Draw()
pdf_name = f"RecoEffComparison{MCDataset}.pdf"
c25b16.Print(f"{outDir}/{pdf_name}")
# Out:
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/RecoEffComparisonLHC25b16.pdf has been created
# <div id="root_plot_1778588073102" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588073102(Core) {
# ...

# %% [markdown]
# ## Purity

# %%
# Purity plot
reload(hutils)
graphPurity25b16Prompt, legPurity25b16Prompt = hutils.PurityPlot(
    listA=f"PairsBarrelSEPMCorrectAssoc_{tckCut}_eePrimaryFromPromptJPsi",
    listB=f"PairsBarrelSEPMIncorrectAssoc_{tckCut}_eePrimaryFromPromptJPsi",
    path=path25b16,
    graph_title="Prompt J/#psi Reconstruction Purity",
    legText="LHC25b16, prompt",
    legPos=[0.6, 0.6, 0.95, 0.7],
    ptBins = usedPtBins
)

# %%
cPurity25b16Prompt = ROOT.TCanvas()
graphPurity25b16Prompt.SetTitle("Prompt J/#psi Reconstruction Purity") #Change previous title
graphPurity25b16Prompt.Draw("AP")
legPurity25b16Prompt.Draw()
cPurity25b16Prompt.Draw()
pdf_name = f"promptPurity{MCDataset}.pdf"
cPurity25b16Prompt.Print(f"{outDir}/{pdf_name}")
# Out:
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/promptPurityLHC25b16.pdf has been created
# <div id="root_plot_1778588074037" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588074037(Core) {
# ...

# %%
# Purity plot
graphPurity25b16NonPrompt, legPurity25b16NonPrompt = hutils.PurityPlot(
    listA=f"PairsBarrelSEPMCorrectAssoc_{tckCut}_eePrimaryFromNonPromptJPsi",
    listB=f"PairsBarrelSEPMIncorrectAssoc_{tckCut}_eePrimaryFromNonPromptJPsi",
    path=path25b16,
    graph_title="NonPrompt J/#psi Reconstruction Purity",
    legText="LHC25b16, non prompt",
    legPos=[0.6, 0.6, 0.95, 0.7],
    ptBins = usedPtBins
)

# %%
cPurity25b16NonPrompt = ROOT.TCanvas()
graphPurity25b16NonPrompt.SetTitle("NonPrompt J/#psi Reconstruction Purity") #Change previous title
graphPurity25b16NonPrompt.Draw("AP")
legPurity25b16NonPrompt.Draw()
cPurity25b16NonPrompt.Draw()
pdf_name = f"nonPromptPurity{MCDataset}.pdf"
cPurity25b16NonPrompt.Print(f"{outDir}/{pdf_name}")
# Out:
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/nonPromptPurityLHC25b16.pdf has been created
# <div id="root_plot_1778588075004" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588075004(Core) {
# ...

# %%
# Purity comparison LHC25b16
cPurity25b16 = ROOT.TCanvas("cPurity25b16", "cPurity25b16", 800, 600)
graphPurity25b16Prompt.SetLineColor(colors[0])
graphPurity25b16Prompt.SetMarkerColor(colors[0])
graphPurity25b16NonPrompt.SetTitle("J/#psi Reconstruction Purity")
graphPurity25b16NonPrompt.Draw("AP") # graph with greater axis must be drawn first
graphPurity25b16Prompt.Draw("P SAME")
legPurity25b16 = legPurity25b16Prompt.Clone("legPurity25b16")
# legendPrompt.Draw()
legPurity25b16.AddEntry(graphPurity25b16NonPrompt, "LHC25b16, non-prompt", "p")
legPurity25b16.Draw()
cPurity25b16.Draw()
pdf_name = f"PurityComparison{MCDataset}.pdf"
cPurity25b16.Print(f"{outDir}/{pdf_name}")
# Out:
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/PurityComparisonLHC25b16.pdf has been created
# <div id="root_plot_1778588075141" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588075141(Core) {
# ...

# %% [markdown]
# ## Event-selection Efficiency

# %%
# Event-selection efficiency
graphSel25b16Prompt, legSel25b16Prompt = hutils.EfficiencyPlot(
    listA="MCTruthGenSel_promptJpsi",
    listB="MCTruthGen_promptJpsi",
    path=path25b16,
    graph_title="Prompt J/#psi Event-Selection Efficiency",
    legText="LHC25b16, prompt",
    ptBins = usedPtBins
)

# %%
cSel25b16Prompt = ROOT.TCanvas()
graphSel25b16Prompt.Draw("AP")
legSel25b16Prompt.Draw()
cSel25b16Prompt.Draw()
pdf_name = f"promptEventSelectionEff{MCDataset}.pdf"
cSel25b16Prompt.Print(f"{outDir}/{pdf_name}")
# Out:
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/promptEventSelectionEffLHC25b16.pdf has been created
# <div id="root_plot_1778588078130" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588078130(Core) {
# ...

# %%
graphSel25b16NonPrompt, legSel25b16NonPrompt = hutils.EfficiencyPlot(
    listA="MCTruthGenSel_nonPromptJpsi",
    listB="MCTruthGen_nonPromptJpsi",
    path=path25b16,
    graph_title="Non-Prompt J/#psi Event-Selection Efficiency",
    legText="LHC25b16, non prompt",
    ptBins = usedPtBins
)

# %%
cSel25b16NonPrompt = ROOT.TCanvas()
graphSel25b16NonPrompt.Draw("AP")
legSel25b16NonPrompt.Draw()
cSel25b16NonPrompt.Draw()
pdf_name = f"nonPromptEventSelectionEff{MCDataset}.pdf"
cSel25b16NonPrompt.Print(f"{outDir}/{pdf_name}")
# Out:
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/nonPromptEventSelectionEffLHC25b16.pdf has been created
# <div id="root_plot_1778588081266" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588081266(Core) {
# ...

# %%
cSel25b16 = ROOT.TCanvas("cSel25b16", "cSel25b16", 800, 600)
graphSel25b16Prompt.SetLineColor(colors[0])
graphSel25b16Prompt.SetMarkerColor(colors[0])
graphSel25b16NonPrompt.SetTitle("J/#psi Event-Selection Efficiency")
graphSel25b16NonPrompt.Draw("AP") # graph with greater axis must be drawn first
graphSel25b16Prompt.Draw("P SAME")
legSel25b16 = legSel25b16Prompt.Clone("legSel25b16")
# legendPrompt.Draw()
legSel25b16.AddEntry(graphSel25b16NonPrompt, "LHC25b16, non-prompt", "p")
legSel25b16.Draw()
cSel25b16.Draw()
pdf_name = f"EventSelectionEffComparison{MCDataset}.pdf"
cSel25b16.Print(f"{outDir}/{pdf_name}")
# Out:
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/EventSelectionEffComparisonLHC25b16.pdf has been created
# <div id="root_plot_1778588081440" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588081440(Core) {
# ...

# %% [markdown]
# ---
# # LHC25b17

# %% [markdown]
# ## LHC25b17, non-prompt

# %%
# dir_path = '~/alice/Jpsi-Jets-Analysis/workDir/MC/DQEfficiency/skimmingByOthers/output'
file25b17 = 'LHC25b17jpsiKineDcaQualitynoPID2-26-05-01.root'
path25b17 = f"{dir_path}/{file25b17}"

# %%
# Reco eff, non prompt
reload(hutils)
graph25b17NonPrompt, leg25b17NonPrompt = hutils.EfficiencyPlot(
    listA=f"PairsBarrelSEPMCorrectAssoc_{tckCut}_eePrimaryFromNonPromptJPsi",
    listB="MCTruthGenSel_nonPromptJpsi",
    path=path25b17,
    graph_title="Non-Prompt J/#psi Reconstruction Efficiency",
    legText="LHC25b17, non-prompt",
    ptBins = usedPtBins
)

c25b17NonPrompt = ROOT.TCanvas()
graph25b17NonPrompt.SetTitle("Non Prompt J/#psi Reconstruction Efficiency")
graph25b17NonPrompt.Draw("AP")
leg25b17NonPrompt.Draw()
c25b17NonPrompt.Draw()
pdf_name = f"nonPromptRecoEffLHC25b17.pdf"
c25b17NonPrompt.Print(f"{outDir}/{pdf_name}")
# Out:
# Error in <TBufferFile::CheckByteCount>: object of class TList read too many bytes: 1776563719 instead of 702821895
# Warning in <TBufferFile::CheckByteCount>: TList::Streamer() not in sync with data on file /home/ferrandi/alice/Jpsi-Jets-Analysis/workDir/MC/DQEfficiency/mySkimming/completeMC/output/LHC25b17jpsiKineDcaQualitynoPID2-26-05-01.root, fix Streamer()
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/nonPromptRecoEffLHC25b17.pdf has been created
# <div id="root_plot_1778588086285" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588086285(Core) {
# ...

# %%
# Incorrectly associated

reload(hutils)
graph25b17IncNonPrompt, leg25b17IncNonPrompt = hutils.EfficiencyPlot(
    listA=f"PairsBarrelSEPMIncorrectAssoc_{tckCut}_eePrimaryFromNonPromptJPsi",
    listB="MCTruthGenSel_nonPromptJpsi",
    path=path25b17,
    graph_title="Non-Prompt J/#psi Reconstruction Efficiency",
    legText="LHC25b17, non-prompt",
    ptBins = usedPtBins
)

c25b17IncNonPrompt = ROOT.TCanvas()
graph25b17IncNonPrompt.SetTitle("Non Prompt J/#psi 'Contamination'")
graph25b17IncNonPrompt.Draw("AP")
leg25b17IncNonPrompt.Draw()
c25b17IncNonPrompt.Draw()
pdf_name = f"nonPromptIncorrectAssocRecoEffLHC25b17.pdf"
c25b17IncNonPrompt.Print(f"{outDir}/{pdf_name}")
# Out:
# Error in <TBufferFile::CheckByteCount>: object of class TList read too many bytes: 1776563719 instead of 702821895
# Warning in <TBufferFile::CheckByteCount>: TList::Streamer() not in sync with data on file /home/ferrandi/alice/Jpsi-Jets-Analysis/workDir/MC/DQEfficiency/mySkimming/completeMC/output/LHC25b17jpsiKineDcaQualitynoPID2-26-05-01.root, fix Streamer()
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/nonPromptIncorrectAssocRecoEffLHC25b17.pdf has been created
# <div id="root_plot_1778591840047" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778591840047(Core) {
# ...

# %%
# Purity plot, non prompt
graphPurity25b17NonPrompt, legPurity25b17NonPrompt = hutils.PurityPlot(
    listA=f"PairsBarrelSEPMCorrectAssoc_{tckCut}_eePrimaryFromNonPromptJPsi",
    listB=f"PairsBarrelSEPMIncorrectAssoc_{tckCut}_eePrimaryFromNonPromptJPsi",
    path=path25b17,
    graph_title="Non-Prompt J/#psi Reconstruction Purity",
    legText="LHC25b17, non prompt",
    legPos=[0.6, 0.6, 0.95, 0.7],
    ptBins = usedPtBins
)

cPurity25b17NonPrompt = ROOT.TCanvas()
graphPurity25b17NonPrompt.SetTitle("NonPrompt J/#psi Reconstruction Purity") #Change previous title
graphPurity25b17NonPrompt.Draw("AP")
legPurity25b17NonPrompt.Draw()
cPurity25b17NonPrompt.Draw()
pdf_name = f"nonPromptPurityLHC25b17.pdf"
cPurity25b17NonPrompt.Print(f"{outDir}/{pdf_name}")
# Out:
# Error in <TBufferFile::CheckByteCount>: object of class TList read too many bytes: 1776563719 instead of 702821895
# Warning in <TBufferFile::CheckByteCount>: TList::Streamer() not in sync with data on file /home/ferrandi/alice/Jpsi-Jets-Analysis/workDir/MC/DQEfficiency/mySkimming/completeMC/output/LHC25b17jpsiKineDcaQualitynoPID2-26-05-01.root, fix Streamer()
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/nonPromptPurityLHC25b17.pdf has been created
# <div id="root_plot_1778588089474" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588089474(Core) {
# ...

# %%
# Event-selection efficiency, non prompt
graphSel25b17NonPrompt, legSel25b17NonPrompt = hutils.EfficiencyPlot(
    listA="MCTruthGenSel_nonPromptJpsi",
    listB="MCTruthGen_nonPromptJpsi",
    path=path25b17,
    graph_title="Non-Prompt J/#psi Event-Selection Efficiency",
    legText="LHC25b17, non prompt",
    ptBins = usedPtBins
)

cSel25b17NonPrompt = ROOT.TCanvas()
graphSel25b17NonPrompt.Draw("AP")
legSel25b17NonPrompt.Draw()
cSel25b17NonPrompt.Draw()
pdf_name = f"nonPromptEventSelectionEffLHC25b17.pdf"
cSel25b17NonPrompt.Print(f"{outDir}/{pdf_name}")
# Out:
# Error in <TBufferFile::CheckByteCount>: object of class TList read too many bytes: 1776563719 instead of 702821895
# Warning in <TBufferFile::CheckByteCount>: TList::Streamer() not in sync with data on file /home/ferrandi/alice/Jpsi-Jets-Analysis/workDir/MC/DQEfficiency/mySkimming/completeMC/output/LHC25b17jpsiKineDcaQualitynoPID2-26-05-01.root, fix Streamer()
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/nonPromptEventSelectionEffLHC25b17.pdf has been created
# <div id="root_plot_1778588093230" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588093230(Core) {
# ...

# %% [markdown]
# ## LHC25b17, prompt

# %%
# Prompt
graph25b17Prompt, leg25b17Prompt = hutils.EfficiencyPlot(
    listA=f"PairsBarrelSEPMCorrectAssoc_{tckCut}_eePrimaryFromPromptJPsi",
    listB="MCTruthGenSel_promptJpsi",
    path=path25b17,
    graph_title="Prompt J/#psi Reconstruction Efficiency",
    legText="LHC25b17, prompt"#,
    # ptBins = usedPtBins
)

c25b17Prompt = ROOT.TCanvas()
# graph25b17Prompt.SetTitle("Prompt J/#psi Reconstruction Efficiency") #Change previous title
graph25b17Prompt.Draw("AP")
leg25b17Prompt.Draw()
c25b17Prompt.Draw()
pdf_name = f"promptRecoEffLHC25b17.pdf"
c25b17Prompt.Print(f"{outDir}/{pdf_name}")
# Out:
# Error in <TBufferFile::CheckByteCount>: object of class TList read too many bytes: 1776563719 instead of 702821895
# Warning in <TBufferFile::CheckByteCount>: TList::Streamer() not in sync with data on file /home/ferrandi/alice/Jpsi-Jets-Analysis/workDir/MC/DQEfficiency/mySkimming/completeMC/output/LHC25b17jpsiKineDcaQualitynoPID2-26-05-01.root, fix Streamer()
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/promptRecoEffLHC25b17.pdf has been created
# <div id="root_plot_1778588096407" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588096407(Core) {
# ...

# %%
# Purity plot, prompt
graphPurity25b17Prompt, legPurity25b17Prompt = hutils.PurityPlot(
    listA=f"PairsBarrelSEPMCorrectAssoc_{tckCut}_eePrimaryFromPromptJPsi",
    listB=f"PairsBarrelSEPMIncorrectAssoc_{tckCut}_eePrimaryFromPromptJPsi",
    path=path25b17,
    graph_title="Prompt J/#psi Reconstruction Purity",
    legText="LHC25b17, prompt",
    legPos=[0.6, 0.6, 0.95, 0.7]
)

cPurity25b17Prompt = ROOT.TCanvas()
graphPurity25b17Prompt.SetTitle("Prompt J/#psi Reconstruction Purity") #Change previous title
graphPurity25b17Prompt.Draw("AP")
legPurity25b17Prompt.Draw()
cPurity25b17Prompt.Draw()
# Out:
# Error in <TBufferFile::CheckByteCount>: object of class TList read too many bytes: 1776563719 instead of 702821895
# Warning in <TBufferFile::CheckByteCount>: TList::Streamer() not in sync with data on file /home/ferrandi/alice/Jpsi-Jets-Analysis/workDir/MC/DQEfficiency/mySkimming/completeMC/output/LHC25b17jpsiKineDcaQualitynoPID2-26-05-01.root, fix Streamer()
# <div id="root_plot_1778588099538" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588099538(Core) {
# ...

# %%
# Event-selection efficiency, prompt
graphSel25b17Prompt, legSel25b17Prompt = hutils.EfficiencyPlot(
    listA="MCTruthGenSel_promptJpsi",
    listB="MCTruthGen_promptJpsi",
    path=path25b17,
    graph_title="Prompt J/#psi Event-Selection Efficiency",
    legText="LHC25b17, prompt"#,
    # legPos=[0.6, 0.6, 0.95, 0.7]
)

cSel25b17Prompt = ROOT.TCanvas()
graphSel25b17Prompt.Draw("AP")
legSel25b17Prompt.Draw()
cSel25b17Prompt.Draw()
# Out:
# Error in <TBufferFile::CheckByteCount>: object of class TList read too many bytes: 1776563719 instead of 702821895
# Warning in <TBufferFile::CheckByteCount>: TList::Streamer() not in sync with data on file /home/ferrandi/alice/Jpsi-Jets-Analysis/workDir/MC/DQEfficiency/mySkimming/completeMC/output/LHC25b17jpsiKineDcaQualitynoPID2-26-05-01.root, fix Streamer()
# <div id="root_plot_1778588104271" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588104271(Core) {
# ...

# %% [markdown]
# ## LHC25b17, Comparison plots

# %%
# # Both plots side by side
# graphs = [graph25b17Prompt, graph25b17NonPrompt]
# legends = [leg25b17NonPrompt, leg25b17Prompt]

# n = len(graphs)
# cAll = ROOT.TCanvas("cAll17", "Side by Side", 500*n , 400)

# cAll.Divide(n, 1)
# for i, (g, leg) in enumerate(zip(graphs, legends), start=1):
#     cAll.cd(i)
#     g.Draw("AP")
#     leg.Draw()

# cAll.Draw()

# %%
# c25b17 = ROOT.TCanvas("c25b17", "c25b17", 800, 600)
# graph25b17Prompt.SetLineColor(colors[0])
# graph25b17Prompt.SetMarkerColor(colors[0])
# graph25b17NonPrompt.SetTitle("J/#psi Reconstruction Efficiency")
# graph25b17NonPrompt.Draw("AP") # graph with greater axis must be drawn first
# graph25b17Prompt.Draw("P SAME")
# leg25b17 = leg25b17Prompt.Clone("leg25b17")
# # legendPrompt.Draw()
# leg25b17.AddEntry(graph25b17NonPrompt, "LHC25b17, non-prompt", "p")
# leg25b17.Draw()
# c25b17.Draw()

# %%
# # Both purity plots side by side
# cPurity25b17 = ROOT.TCanvas("cPurity25b17", "cPurity25b17", 800, 600)
# graphPurity25b17Prompt.SetLineColor(colors[0])
# graphPurity25b17Prompt.SetMarkerColor(colors[0])
# graphPurity25b17NonPrompt.SetTitle("J/#psi Reconstruction Purity")
# graphPurity25b17NonPrompt.Draw("AP") # graph with greater axis must be drawn first
# graphPurity25b17Prompt.Draw("P SAME")
# legPurity25b17 = legPurity25b17Prompt.Clone("legPurity25b17")
# # legendPrompt.Draw()
# legPurity25b17.AddEntry(graphPurity25b17NonPrompt, "LHC25b17, non-prompt", "p")
# legPurity25b17.Draw()
# cPurity25b17.Draw()

# %%
# # Both event-selection-efficiency plots
# cSel25b17 = ROOT.TCanvas("cSel25b17", "cSel25b17", 800, 600)
# graphSel25b17Prompt.SetLineColor(colors[0])
# graphSel25b17Prompt.SetMarkerColor(colors[0])
# graphSel25b17NonPrompt.SetTitle("J/#psi Event-Selection Efficiency")
# graphSel25b17NonPrompt.Draw("AP") # graph with greater axis must be drawn first
# graphSel25b17Prompt.Draw("P SAME")
# legSel25b17 = legSel25b17Prompt.Clone("legSel25b17")
# # legendPrompt.Draw()
# legSel25b17.AddEntry(graphSel25b17NonPrompt, "LHC25b17, non-prompt", "p")
# legSel25b17.Draw()
# cSel25b17.Draw()

# %% [markdown]
# ---
# # LHC25b16 + LHC25b17

# %%
# 16+17 Reco Eff
# c25b1617 = ROOT.TCanvas("c25b1617", "c25b1617", 800, 600)
c25b1617 = ROOT.TCanvas()

graph25b17NonPrompt.SetLineColor(colors[1])
graph25b17NonPrompt.SetMarkerColor(colors[1])

graph25b16NonPrompt.SetLineColor(colors[2])
graph25b16NonPrompt.SetMarkerColor(colors[2])

graph25b17Prompt.SetLineColor(colors[3])
graph25b17Prompt.SetMarkerColor(colors[3])

# graph25b17NonPrompt.SetTitle("J/#psi Reconstruction Efficiency")

# Change axis of first graph to change overall axis
graph25b16NonPrompt.SetMinimum(0.0)
graph25b16NonPrompt.SetMaximum(1.0)


graph25b16NonPrompt.Draw("AP") # graph with greater axis must be drawn first

graph25b16Prompt.Draw("P SAME")
graph25b17NonPrompt.Draw("P SAME")
graph25b17Prompt.Draw("P SAME")

leg25b1617 = leg25b16Prompt.Clone("leg25b16")

leg25b1617.AddEntry(graph25b16Prompt, "LHC25b16, prompt", "p")
leg25b1617.AddEntry(graph25b16NonPrompt, "LHC25b16, non prompt", "p")
leg25b1617.AddEntry(graph25b17NonPrompt, "LHC25b17, non prompt", "p")
leg25b1617.AddEntry(graph25b17Prompt, "LHC25b17, prompt", "p")

leg25b1617.Draw()
c25b1617.Update()
c25b1617.Draw()
pdf_name = f"RecoEffComparisonLHC25b16-17.pdf"
c25b1617.Print(pdf_name)
# Out:
# Info in <TCanvas::Print>: pdf file RecoEffComparisonLHC25b16-17.pdf has been created
# <div id="root_plot_1778588341814" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778588341814(Core) {
# ...

# %%
# 16+17 Incorrect Assoc "Reco Eff"
c25b1617Inc = ROOT.TCanvas()

graph25b17IncNonPrompt.SetLineColor(colors[1])
graph25b17IncNonPrompt.SetMarkerColor(colors[1])

# graph25b16NonPrompt.SetLineColor(colors[2])
# graph25b16NonPrompt.SetMarkerColor(colors[2])

# graph25b17Prompt.SetLineColor(colors[3])
# graph25b17Prompt.SetMarkerColor(colors[3])

# graph25b17IncNonPrompt.SetTitle("J/#psi Reconstruction Efficiency")

# Change axis of first graph to change overall axis
# graph25b16NonPrompt.SetMinimum(0.0)
# graph25b16NonPrompt.SetMaximum(1.0)


# graph25b16NonPrompt.Draw("AP") # graph with greater axis must be drawn first

graph25b16IncPrompt.Draw("AP")
graph25b17IncNonPrompt.Draw("P SAME")
# graph25b17Prompt.Draw("P SAME")

leg25b1617Inc = leg25b16IncPrompt.Clone("leg25b16")

leg25b1617Inc.AddEntry(graph25b16IncPrompt, "LHC25b16, prompt", "p")
# leg25b1617Inc.AddEntry(graph25b16NonPrompt, "LHC25b16, non prompt", "p")
leg25b1617Inc.AddEntry(graph25b17IncNonPrompt, "LHC25b17, non prompt", "p")
# leg25b1617Inc.AddEntry(graph25b17Prompt, "LHC25b17, prompt", "p")

leg25b1617Inc.Draw()
c25b1617Inc.Update()
c25b1617Inc.Draw()
pdf_name = f"IncorrectAssocComparisonLHC25b16-17.pdf"
c25b1617Inc.Print(pdf_name)
# Out:
# Info in <TCanvas::Print>: pdf file IncorrectAssocComparisonLHC25b16-17.pdf has been created
# <div id="root_plot_1778592435289" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778592435289(Core) {
# ...

# %%
# 16+17 Reco Eff Propaganda Plot
# 16+17 Reco Eff
# c25b1617Propag = ROOT.TCanvas("c25b1617Propag", "c25b1617Propag", 800, 600)
c25b1617Propag = ROOT.TCanvas()

# graph25b16Prompt.SetTitle("J/#psi Reconstruction Efficiency") # Workaround: change the title of the first plot, draw it, so that the canvas gets its title. Then, in next cell, to maintain to title correct, change it again


graph25b16Prompt.GetYaxis().SetRangeUser(0.12, 0.33)
graph25b16Prompt.Draw("AP") # graph with greater axis must be drawn first
graph25b17NonPrompt.Draw("P SAME")

leg25b1617Propag = leg25b16Prompt.Clone("leg25b16")
leg25b1617Propag.SetX1(0.10)
leg25b1617Propag.SetY1(0.7)
leg25b1617Propag.SetX2(0.5)
leg25b1617Propag.SetY2(0.90)
leg25b1617Propag.GetListOfPrimitives().RemoveAt(3)

leg25b1617Propag.AddEntry(graph25b16Prompt, "Prompt J/#psi", "p")
leg25b1617Propag.AddEntry(graph25b17NonPrompt, "Non-prompt J/#psi", "p")

leg25b1617Propag.Draw()
c25b1617Propag.Draw()
pdf_name = f"RecoEffComparisonLHC25b16-17Propaganda.pdf"
c25b1617Propag.Print(f"{outDir}/{pdf_name}")
# Out:
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/RecoEffComparisonLHC25b16-17Propaganda.pdf has been created
# <div id="root_plot_1778166882709" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778166882709(Core) {
# ...

# %%
# 16+17 Reco Eff Propaganda Plot
# 16+17 Reco Eff
# c25b1617Propag = ROOT.TCanvas("c25b1617Propag", "c25b1617Propag", 800, 600)
c25b1617PropagLogx = ROOT.TCanvas()

ROOT.gPad.SetLogx()

# graph25b16Prompt.SetTitle("J/#psi Reconstruction Efficiency") # Workaround: change the title of the first plot, draw it, so that the canvas gets its title. Then, in next cell, to maintain to title correct, change it again


graph25b16Prompt.GetYaxis().SetRangeUser(0.12, 0.33)
graph25b16Prompt.Draw("AP") # graph with greater axis must be drawn first
graph25b17NonPrompt.Draw("P SAME")

leg25b1617Propag = leg25b16Prompt.Clone("leg25b16")
leg25b1617Propag.SetX1(0.10)
leg25b1617Propag.SetY1(0.7)
leg25b1617Propag.SetX2(0.5)
leg25b1617Propag.SetY2(0.90)
leg25b1617Propag.GetListOfPrimitives().RemoveAt(3)

leg25b1617Propag.AddEntry(graph25b16Prompt, "Prompt J/#psi", "p")
leg25b1617Propag.AddEntry(graph25b17NonPrompt, "Non-prompt J/#psi", "p")

leg25b1617Propag.Draw()
c25b1617PropagLogx.Draw()
pdf_name = f"RecoEffComparisonLHC25b16-17PropagandaLogx.pdf"
c25b1617PropagLogx.Print(f"{outDir}/{pdf_name}")
# Out:
# Info in <TCanvas::Print>: pdf file output/efficienciesJpsi/cutOnY/jpsiKineDcaQualitynoPID2/RecoEffComparisonLHC25b16-17PropagandaLogx.pdf has been created
# <div id="root_plot_1778166852439" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1778166852439(Core) {
# ...

# %%
graph25b16Prompt.SetTitle("Prompt J/#psi Reconstruction Efficiency")

# %%
# Purity, 16+17
cPurity25b1617 = ROOT.TCanvas("cPurity25b1617", "cPurity25b1617", 800, 600)

graphPurity25b16NonPrompt.SetLineColor(colors[1])
graphPurity25b16NonPrompt.SetMarkerColor(colors[1])

graphPurity25b17NonPrompt.SetLineColor(colors[2])
graphPurity25b17NonPrompt.SetMarkerColor(colors[2])

graphPurity25b17Prompt.SetLineColor(colors[3])
graphPurity25b17Prompt.SetMarkerColor(colors[3])

# graphPurity25b17NonPrompt.SetTitle("J/#psi Reconstruction Efficiency")

graphPurity25b16Prompt.SetMinimum(0.0)
graphPurity25b16Prompt.SetMaximum(1.0)

graphPurity25b16Prompt.Draw("AP") # graphPurity with greater axis must be drawn first

graphPurity25b16NonPrompt.Draw("P SAME")
graphPurity25b17NonPrompt.Draw("P SAME")
graphPurity25b17Prompt.Draw("P SAME")

leg25b1617 = leg25b16Prompt.Clone("leg25b16")

leg25b1617.AddEntry(graphPurity25b16NonPrompt, "LHC25b16, non prompt", "p")
leg25b1617.AddEntry(graphPurity25b17NonPrompt, "LHC25b17, non prompt", "p")
leg25b1617.AddEntry(graphPurity25b17Prompt, "LHC25b17, prompt", "p")

leg25b1617.SetY1(0.2)
leg25b1617.SetY2(0.4)

leg25b1617.Draw()
cPurity25b1617.Draw()
pdf_name = f"PurityComparisonLHC25b16-17.pdf"
cPurity25b1617.Print(f"{outDir}/{pdf_name}")

# %%
# Evt-Sel Eff, 16+17
cSel25b1617 = ROOT.TCanvas("cSel25b1617", "cSel25b1617", 800, 600)

graphSel25b16NonPrompt.SetLineColor(colors[1])
graphSel25b16NonPrompt.SetMarkerColor(colors[1])

graphSel25b17NonPrompt.SetLineColor(colors[2])
graphSel25b17NonPrompt.SetMarkerColor(colors[2])
# graphSel25b17NonPrompt.SetTitle("J/#psi Reconstruction Efficiency")

graphSel25b17Prompt.SetLineColor(colors[3])
graphSel25b17Prompt.SetMarkerColor(colors[3])

graphSel25b16NonPrompt.SetMinimum(0.0)
graphSel25b16NonPrompt.SetMaximum(1.0)

graphSel25b16NonPrompt.Draw("AP") # graphSel with greater axis must be drawn first

graphSel25b16Prompt.Draw("P SAME")
graphSel25b17NonPrompt.Draw("P SAME")
graphSel25b17Prompt.Draw("P SAME")

leg25b1617 = leg25b16Prompt.Clone("leg25b16")

leg25b1617.AddEntry(graphSel25b16NonPrompt, "LHC25b16, non prompt", "p")
leg25b1617.AddEntry(graphSel25b17NonPrompt, "LHC25b17, non prompt", "p")
leg25b1617.AddEntry(graphSel25b17Prompt, "LHC25b17, prompt", "p")

leg25b1617.SetY1(0.2)
leg25b1617.SetY2(0.4)

leg25b1617.Draw()
cSel25b1617.Draw()
pdf_name = f"EvtSelEffComparisonLHC25b16-17.pdf"
cSel25b1617.Print(f"{outDir}/{pdf_name}")
